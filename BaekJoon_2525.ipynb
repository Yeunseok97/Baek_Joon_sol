# %%
a, b = map(int, input().split())
c = int(input())
if a>=0 and a<=23 and b>=0 and b <=59 and c>=0 and c<= 1000:
  quotient, remainder = divmod(b+c, 60)
  a += quotient
  b = remainder

  if a>=24:
    a -= 24
    print(a, b)
    
  else:
    print(a, b)
# Out:
# 23 48
# 25
# 0 13
